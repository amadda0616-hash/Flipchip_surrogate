# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
import glob

# %%
datas = []

for a in range(0,487):
    file_path = f'./Battery/데이터셋/ML_DATA_Extract_Row_{a}.csv'
    
    # 파일이 존재하는지 확인하는 예외 처리를 추가하면 안전합니다
    if os.path.exists(file_path):
        data = pd.read_csv(file_path)
        datas.append(data)

# 데이터프레임들을 하나로 합치기
df_combined = pd.concat(datas, ignore_index=True)
df_combined
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 12
#       9         datas.append(data)
#      11 # 데이터프레임들을 하나로 합치기
# ---> 12 df_combined = pd.concat(datas, ignore_index=True)
#      13 df_combined
#
# File d:\AI_Study\miniconda3\envs\DL\Lib\site-packages\pandas\core\reshape\concat.py:407, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     402 else:  # pragma: no cover
#     403     raise ValueError(
#     404         "Only can inner (intersect) or outer (union) join the other axis"
#     405     )
# --> 407 objs, keys, ndims = _clean_keys_and_objs(objs, keys)
#     409 if sort is lib.no_default:
#     410     if axis == 0:
#
# File d:\AI_Study\miniconda3\envs\DL\Lib\site-packages\pandas\core\reshape\concat.py:808, in _clean_keys_and_objs(objs, keys)
#     805     objs = list(objs)
#     807 if len(objs) == 0:
# --> 808     raise ValueError("No objects to concatenate")
#     810 if keys is not None:
#     811     if not isinstance(keys, Index):
#
# ValueError: No objects to concatenate

# %%
df_combined.head()
# Out:
#      Time    TempBase   WarpMax   T_Tip_Peel   T_Tip_Shear   T_Tip_SEQV  \
# 0  0.1000  119.772491 -0.093900   -34.039048     -4.611648    35.953964
# 1  0.2000  119.342079 -0.091918   -33.117296     -4.321274    34.870854
# 2  0.3500  116.146805 -0.087046   -30.063202     -3.425492    31.347935
# 3  0.5750  102.367302 -0.077408   -21.335327     -1.069542    21.684202
# 4  0.9125  102.367302 -0.077405   -21.258666     -1.108848    21.618139
#
#     T_Tip_Strain   T_Avg_Peel   T_Avg_Shear   B_Tip_Peel   B_Tip_Shear  \
# 0       0.001978     0.018626     -2.479831    -5.445917     -2.658814
# 1       0.001930     0.018245     -2.405363    -5.392631     -2.594982
# 2       0.001758     0.016425     -2.151174    -5.191143     -2.391990
# 3       0.001290     0.011473     -1.439919    -4.453914     -1.874074
# 4       0.001305     0.011256     -1.440604    -4.407878     -1.863347
#
#     B_Tip_SEQV   B_Tip_Strain   B_Avg_Peel   B_Avg_Shear     Die_SX  \
# 0    27.851064       0.001952     0.026744     -2.414072  58.597932
# 1    27.350767       0.001923     0.026047     -2.349079  57.581262
# 2    25.760874       0.001823     0.023751     -2.123403  54.532040
# 3    21.437436       0.001539     0.016897     -1.481788  46.687801
# 4    21.377225       0.001540     0.017055     -1.481196  46.690991
#
#     Die_SY_Max
# 0   -85.012494
# 1   -82.475316
# 2   -75.202100
# 3   -56.980162
# 4   -56.968759

# %%
df_combined.tail()
# Out:
#              Time   TempBase   WarpMax   T_Tip_Peel   T_Tip_Shear  \
# 221621  298.41250  22.001497 -0.060728    19.993435      6.595332
# 221622  298.91250  22.001497 -0.060729    19.991191      6.594960
# 221623  299.41250  22.001497 -0.060730    19.988981      6.594595
# 221624  299.70625  22.001497 -0.060731    19.987697      6.594384
# 221625  300.00000  22.001497 -0.060731    19.986425      6.594175
#
#          T_Tip_SEQV   T_Tip_Strain   T_Avg_Peel   T_Avg_Shear   B_Tip_Peel  \
# 221621    26.180698       0.003246    -0.028462      1.161866     0.880817
# 221622    26.178368       0.003247    -0.028461      1.161874     0.880439
# 221623    26.176077       0.003247    -0.028461      1.161881     0.880066
# 221624    26.174747       0.003247    -0.028460      1.161886     0.879849
# 221625    26.173430       0.003247    -0.028460      1.161890     0.879633
#
#          B_Tip_Shear   B_Tip_SEQV   B_Tip_Strain   B_Avg_Peel   B_Avg_Shear  \
# 221621     -0.055972     6.080573        0.00069    -0.005688      1.136165
# 221622     -0.055893     6.080661        0.00069    -0.005687      1.136169
# 221623     -0.055813     6.080746        0.00069    -0.005686      1.136173
# 221624     -0.055767     6.080794        0.00069    -0.005685      1.136176
# 221625     -0.055721     6.080841        0.00069    -0.005685      1.136179
#
#           Die_SX   Die_SY_Max
# 221621  6.934369    37.434713
# 221622  6.929718    37.415032
# 221623  6.925078    37.395483
# 221624  6.922356    37.384046
# 221625  6.919636    37.372651

# %%
datas = []

df = pd.read_csv('./Battery/Master_DOE_1200.csv')
df.head()
# Out:
#        P1      P2      P3      P4      P5      P6
# 0  0.8317  0.0842  0.6021  0.1075  1.7454  0.0585
# 1  0.8143  0.0777  0.7136  0.1333  1.4174  0.0696
# 2  0.8013  0.0512  0.6363  0.2312  1.3751  0.0560
# 3  1.0509  0.0569  0.6031  0.2220  1.2660  0.0777
# 4  0.8744  0.0670  0.6206  0.2669  1.4158  0.0779

# %%
df.tail()
# Out:
#           P1      P2      P3      P4      P5      P6
# 1195  0.9105  0.0724  0.6618  0.1579  1.5180  0.0507
# 1196  0.8535  0.0812  0.6761  0.1703  1.7806  0.0537
# 1197  0.8733  0.0796  0.6174  0.2134  1.6338  0.0657
# 1198  1.0840  0.0760  0.7187  0.1488  1.6888  0.0733
# 1199  0.9104  0.0503  0.7195  0.1772  1.6129  0.0649

# %%
data = pd.read_csv('.\Battery\데이터셋\ML_DATA_Extract_Row_0(비교용).csv')
data.head()
# Out:
#      Time    TempBase   WarpMax   T_Tip_Peel   T_Tip_Shear   T_Tip_SEQV  \
# 0  0.1000  119.783188 -0.117491   -33.906822     -4.554427    35.676788
# 1  0.2000  119.365982 -0.114489   -32.821039     -4.190090    34.399391
# 2  0.3500  116.013115 -0.107182   -29.215017     -3.082544    30.259626
# 3  0.5750  100.949310 -0.093217   -18.910070     -0.244393    19.104284
# 4  0.9125  100.949310 -0.093213   -18.852267     -0.290878    19.049131
#
#     T_Tip_Strain   T_Avg_Peel   T_Avg_Shear   B_Tip_Peel   B_Tip_Shear  \
# 0       0.002045     0.006655     -2.664144    -4.176999     -2.040079
# 1       0.001985     0.006968     -2.571259    -4.121848     -1.983519
# 2       0.001774     0.006249     -2.259908    -3.933210     -1.775690
# 3       0.001226     0.003298     -1.398259    -3.295966     -1.172539
# 4       0.001240     0.003495     -1.398741    -3.267223     -1.165693
#
#     B_Tip_SEQV   B_Tip_Strain   B_Avg_Peel   B_Avg_Shear     Die_SX  \
# 0    24.093281       0.001651    -0.013850     -2.666389  60.788027
# 1    23.631296       0.001624    -0.013271     -2.582500  59.493175
# 2    22.038879       0.001525    -0.011675     -2.296628  55.720295
# 3    17.294662       0.001220    -0.008947     -1.491133  46.510018
# 4    17.252942       0.001220    -0.008968     -1.490320  46.512853
#
#     Die_SY_Max
# 0   -90.517540
# 1   -87.189336
# 2   -77.932456
# 3   -55.918074
# 4   -55.899300

# %%
np.random.seed(42)
n_samples = 800
data = pd.DataFrame({
    'P1': np.random.uniform(10, 50, n_samples),
    'P2': np.random.uniform(100, 200, n_samples),
    'P3': np.random.uniform(0.1, 0.5, n_samples),
    'P4': np.random.uniform(5, 15, n_samples),
    'P5': np.random.uniform(1, 5, n_samples),
    'P6': np.random.uniform(20, 80, n_samples),
    'Max_Peak': np.random.normal(500, 50, n_samples) # 예측 대상(Y)
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 np.random.seed(42)
#       2 n_samples = 800
#       3 data = pd.DataFrame({
#       4     'P1': np.random.uniform(10, 50, n_samples),
#       5     'P2': np.random.uniform(100, 200, n_samples),
#    (...)     10     'Max_Peak': np.random.normal(500, 50, n_samples) # 예측 대상(Y)
#      11 })
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### 탐색적 데이터 분석(EDA)

# %%
# 기본 정보
print('='*60)
print('데이터 정보')
print('='*60)
data.info()
# Out:
# ============================================================
# 데이터 정보
# ============================================================
# <class 'pandas.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Time           617 non-null    float64
#  1    TempBase      617 non-null    float64
#  2    WarpMax       617 non-null    float64
#  3    T_Tip_Peel    617 non-null    float64
#  4    T_Tip_Shear   617 non-null    float64
#  5    T_Tip_SEQV    617 non-null    float64
#  6    T_Tip_Strain  617 non-null    float64
#  7    T_Avg_Peel    617 non-null    float64
#  8    T_Avg_Shear   617 non-null    float64
#  9    B_Tip_Peel    617 non-null    float64
#  10   B_Tip_Shear   617 non-null    float64
#  11   B_Tip_SEQV    617 non-null    float64
#  12   B_Tip_Strain  617 non-null    float64
#  13   B_Avg_Peel    617 non-null    float64
#  14   B_Avg_Shear   617 non-null    float64
#  15   Die_SX        617 non-null    float64
#  16   Die_SY_Max    617 non-null    float64
# dtypes: float64(17)
# memory usage: 82.1 KB

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   P1      1200 non-null   float64
#  1   P2      1200 non-null   float64
#  2   P3      1200 non-null   float64
#  3   P4      1200 non-null   float64
#  4   P5      1200 non-null   float64
#  5   P6      1200 non-null   float64
# dtypes: float64(6)
# memory usage: 56.4 KB

# %%
df_combined.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 221626 entries, 0 to 221625
# Data columns (total 17 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Time           221626 non-null  float64
#  1    TempBase      221626 non-null  float64
#  2    WarpMax       221626 non-null  float64
#  3    T_Tip_Peel    221626 non-null  float64
#  4    T_Tip_Shear   221626 non-null  float64
#  5    T_Tip_SEQV    221626 non-null  float64
#  6    T_Tip_Strain  221626 non-null  float64
#  7    T_Avg_Peel    221626 non-null  float64
#  8    T_Avg_Shear   221626 non-null  float64
#  9    B_Tip_Peel    221626 non-null  float64
#  10   B_Tip_Shear   221626 non-null  float64
#  11   B_Tip_SEQV    221626 non-null  float64
#  12   B_Tip_Strain  221626 non-null  float64
#  13   B_Avg_Peel    221626 non-null  float64
#  14   B_Avg_Shear   221626 non-null  float64
#  15   Die_SX        221626 non-null  float64
#  16   Die_SY_Max    221626 non-null  float64
# dtypes: float64(17)
# memory usage: 28.7 MB
